# %%
import pandas as pd
import numpy as np
import joblib
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

# %% [markdown]
# Part 1

# %%
# Load joblib file
loaded = joblib.load("saved_model.joblib")

# Display the keys of the dictionary
print("Keys:", loaded.keys())
# Out:
# Keys: dict_keys(['preprocessor', 'X_train', 'X_test', 'y_train', 'y_test', 'LinearRegression', 'RandomForestRegressor'])

# %%
#Assign each of the keys from the dictionary as a separate variable.
preprocessor = loaded['preprocessor']
X_train = loaded['X_train']
X_test = loaded['X_test']
y_train = loaded['y_train']
y_test = loaded['y_test']
lin_reg = loaded['LinearRegression']
rf_reg = loaded['RandomForestRegressor']

# %%
## Use the preprocessor to transform X_train into X_train_df and X_test into X_test_df
feature_names = preprocessor.get_feature_names_out()

X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          index=X_train.index,
                          columns=feature_names)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                         index=X_test.index,
                          columns=feature_names)

# %%
X_test_df.head()
# Out:
#       Lot Area  Lot Frontage  Overall Cond  Total Bsmt SF  Gr Liv Area  \
# 343  13,860.00         75.00          7.00       1,952.00     2,704.00
# 1413  8,405.00         50.00          8.00         861.00     1,367.00
# 2583 11,310.00         75.00          5.00       1,367.00     1,375.00
# 2020  6,180.00         60.00          5.00         960.00       986.00
# 348   8,530.00         69.23          5.00         384.00     1,474.00
#
#       TotRms AbvGrd  Central Air_Y  Land Contour_Bnk  Land Contour_HLS  \
# 343            9.00           1.00              0.00              0.00
# 1413           7.00           1.00              0.00              0.00
# 2583           5.00           1.00              0.00              0.00
# 2020           5.00           0.00              0.00              0.00
# 348            7.00           1.00              0.00              0.00
#
#       Land Contour_Low  Land Contour_Lvl
# 343               0.00              1.00
# ...

# %%
X_train_df.head()
# Out:
#       Lot Area  Lot Frontage  Overall Cond  Total Bsmt SF  Gr Liv Area  \
# 853  16,269.00         69.23          5.00         907.00       907.00
# 1055 13,891.00        107.00          5.00       1,710.00     1,710.00
# 2483  8,900.00         69.23          4.00       1,056.00     1,056.00
# 2351 11,475.00         85.00          6.00         713.00     1,552.00
# 1700 13,654.00        118.00          5.00       1,704.00     2,758.00
#
#       TotRms AbvGrd  Central Air_Y  Land Contour_Bnk  Land Contour_HLS  \
# 853            5.00           1.00              0.00              0.00
# 1055           6.00           1.00              0.00              0.00
# 2483           5.00           1.00              0.00              0.00
# 2351           6.00           1.00              0.00              0.00
# 1700           9.00           1.00              0.00              0.00
#
#       Land Contour_Low  Land Contour_Lvl
# 853               0.00              1.00
# ...

# %%
coef = pd.Series(lin_reg.coef_, index= lin_reg.feature_names_in_)
coef.loc['intercept'] = lin_reg.intercept_

# %%
coef
# Out:
# Lot Area                 0.11
# Lot Frontage           109.31
# Overall Cond         1,737.31
# Total Bsmt SF           59.75
# Gr Liv Area            101.28
# TotRms AbvGrd       -6,299.91
# Central Air_Y       31,927.22
# Land Contour_Bnk   -72,620.47
# Land Contour_HLS     4,243.63
# Land Contour_Low   -43,310.96
# Land Contour_Lvl   -42,264.19
# intercept                0.00
# dtype: float64

# %%
#Change the Pandas option for float format to display the coefficients with pandas in a readable form:
#comma separator for thousands
#and 2 decimal places.
pd.set_option('display.float_format',lambda x: f"{x:,.2f}")

# %%
coef
# Out:
# Lot Area                 0.11
# Lot Frontage           109.31
# Overall Cond         1,737.31
# Total Bsmt SF           59.75
# Gr Liv Area            101.28
# TotRms AbvGrd       -6,299.91
# Central Air_Y       31,927.22
# Land Contour_Bnk   -72,620.47
# Land Contour_HLS     4,243.63
# Land Contour_Low   -43,310.96
# Land Contour_Lvl   -42,264.19
# intercept                0.00
# dtype: float64

# %%
# plot coff
def plot_coeffs(coeffs, top_n=None,  figsize=(4,5), intercept=False):
    if (intercept==False) & ('intercept' in coeffs.index):
        coeffs = coeffs.drop('intercept')
        
    if top_n==None:
        ## sort all features and set title
        plot_vals = coeffs.sort_values()
        title = "All Coefficients - Ranked by Magnitude"
    else:
        ## rank the coeffs and select the top_n
        coeff_rank = coeffs.abs().rank().sort_values(ascending=False)
        top_n_features = coeff_rank.head(top_n)
        plot_vals = coeffs.loc[top_n_features.index].sort_values()
        ## sort features and keep top_n and set title
        title = f"Top {top_n} Largest Coefficients"
        
    ## plotting top N importances
    ax = plot_vals.plot(kind='barh', figsize=figsize)
    ax.set(xlabel='Coefficient', 
           ylabel='Feature Names', 
           title=title)
    ax.axvline(0, color='k')
    
    ## return ax in case want to continue to update/modify figure
    return ax

# %%
plot_coeffs(coef)
# Out:
# <Axes: title={'center': 'All Coefficients - Ranked by Magnitude'}, xlabel='Coefficient', ylabel='Feature Names'>

# %% [raw]
# Provide a quantitative interpretation (both magnitude and directionality) of the three largest positive coefficients explaining how that feature impacts the target.
# Provide a quantitative interpretation (both magnitude and directionality)  of the three largest negative coefficients explaining how that feature impacts the target.

# %% [raw]
# The central air is the most impactful coefficient to make the price higher, and it comes after the land contour and lastly the overall conditions
# Homes on level land are expected to be valued less than others while houses in low-lying areas are more cheap and homes near banks for some reason are the cheapest

# %% [markdown]
# Explain the Random Forest Model

# %% [raw]
# Extract and create a bar graph of the feature importances, sorted from largest to smallest.

# %%
def get_importances(rf_reg):
    importances = pd.Series(rf_reg.feature_importances_, index= rf_reg.feature_names_in_)
    return importances


def plot_importances(importances, sort_values=True, top_n=None, figsize=(6,4),
                     title="Feature Importance", xlabel='Importance'):
    if sort_values:
        importances = importances.sort_values()

    if top_n is not None:
        importances = importances.tail(top_n)


    ax = importances.plot(kind='barh', figsize=figsize)
    ax.axvline(0, color='k')
    ax.set(xlabel=xlabel, title=title);
    plt.show()
    return ax

# %%
get_importances(rf_reg)
# Out:
# Lot Area           0.06
# Lot Frontage       0.05
# Overall Cond       0.03
# Total Bsmt SF      0.36
# Gr Liv Area        0.44
# TotRms AbvGrd      0.03
# Central Air_Y      0.01
# Land Contour_Bnk   0.01
# Land Contour_HLS   0.01
# Land Contour_Low   0.00
# Land Contour_Lvl   0.00
# dtype: float64

# %%
plot_importances(importances)
# Out:
# <Axes: title={'center': 'Feature Importance'}, xlabel='Importance'>

# %% [raw]
# Land Contour_HLS and Land Contour_BnK and Land Contour_Low  exist in both importance and coeff

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
len(X_train_df)
# Out:
# 2197

# %%
X_shap = shap.sample(X_train_df,nsamples=500,random_state=321)
X_shap.head()
# Out:
#        Lot Area  Lot Frontage  Overall Cond  Total Bsmt SF  Gr Liv Area  \
# 297   19,645.00         85.00          6.00         423.00     1,652.00
# 2846   8,400.00         60.00          5.00         940.00     1,595.00
# 1319   5,700.00         69.23          7.00         572.00     1,111.00
# 1570 164,660.00         69.23          6.00       1,499.00     1,786.00
# 1139   8,453.00         65.00          5.00         754.00     1,609.00
#
#       TotRms AbvGrd  Central Air_Y  Land Contour_Bnk  Land Contour_HLS  \
# 297            6.00           1.00              0.00              0.00
# 2846           6.00           1.00              1.00              0.00
# 1319           5.00           1.00              0.00              0.00
# 1570           7.00           1.00              0.00              1.00
# 1139           6.00           1.00              0.00              0.00
#
#       Land Contour_Low  Land Contour_Lvl
# 297               0.00              1.00
# ...

# %%
y_shap = y_train.loc[X_shap.index]
y_shap
# Out:
# 297     203135
# 2846    140000
# 1319    116900
# 1570    228950
# 1139    182000
#          ...
# 2498    260000
# 2357    181000
# 564     235000
# 2282    168000
# 2080    118000
# Name: SalePrice, Length: 500, dtype: int64

# %%
explainer = shap.Explainer(rf_reg)
explainer

# %%
shap_values = explainer(X_shap,y_shap)
type(shap_values)
# Out:
# shap._explanation.Explanation

# %%
shap_values[0]
# Out:
# .values =
# array([ 8.59889097e+03,  4.62179937e+03,  7.96685647e+02, -2.85999852e+04,
#         1.81170934e+04,  2.99904579e+03,  2.10693850e+03,  4.06329912e+02,
#        -5.02293889e+02, -7.43101131e+00, -8.87577769e+01])
#
# .base_values =
# array([181545.47430587])
#
# .data =
# array([1.9645e+04, 8.5000e+01, 6.0000e+00, 4.2300e+02, 1.6520e+03,
#        6.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        1.0000e+00])

# %%
pd.DataFrame(shap_values.values, columns = X_shap.columns)
# Out:
#      Lot Area  Lot Frontage  Overall Cond  Total Bsmt SF  Gr Liv Area  \
# 0    8,598.89      4,621.80        796.69     -28,599.99    18,117.09
# 1   -1,292.13     -6,626.87      1,773.88     -25,365.16     6,336.49
# 2   -7,523.63      1,199.48        417.99     -33,897.08   -25,365.46
# 3   -1,448.56     -4,023.10     -3,350.61      42,152.57    21,199.12
# 4    1,708.87          7.50      3,157.73     -26,079.56    18,849.73
# ..        ...           ...           ...            ...          ...
# 495  6,558.62     12,204.92    -37,372.46      61,198.18    99,260.30
# 496  4,814.51      2,420.10        438.26      -8,880.17   -15,987.62
# 497  6,364.06      2,050.37        780.96     -10,520.06    37,364.48
# 498  1,830.90       -151.74    -29,003.11         912.24    -3,645.29
# 499 -6,407.15     -3,581.30      1,577.14     -23,947.03   -39,004.95
#
#      TotRms AbvGrd  Central Air_Y  Land Contour_Bnk  Land Contour_HLS  \
# ...

# %%
shap.summary_plot(shap_values,features= X_shap, plot_type='bar')

# %%
shap.summary_plot(shap_values,X_shap)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# GR liv Area has the highest negative effect on the price, after that comes the Total Bsmt SF but the overall condition have the most impactful positive effect more than the lot Area

# %% [markdown]
# Part 2

# %%
df = pd.read_csv("zillow_home_values-zipcode.csv")

# %%
df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91940         0       77449        zip        TX    TX       NaN
# 1     91982         1       77494        zip        TX    TX       NaN
# 2     93144         2       79936        zip        TX    TX   El Paso
# 3     62080         3       11368        zip        NY    NY  New York
# 4     62093         4       11385        zip        NY    NY  New York
#
#                                    Metro        CountyName   31012000  ...  \
# 0   Houston-The Woodlands-Sugar Land, TX     Harris County 107,261.00  ...
# 1   Houston-The Woodlands-Sugar Land, TX  Fort Bend County 222,569.00  ...
# 2                            El Paso, TX    El Paso County  90,009.00  ...
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County 188,096.00  ...
# 4  New York-Newark-Jersey City, NY-NJ-PA     Queens County 275,983.00  ...
#
#     28022022   31032022   30042022   31052022   30062022   31072022  \
# ...

# %%
melted = pd.melt(df,id_vars=['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
       'State', 'City', 'Metro', 'CountyName'],var_name='Date',
                      value_name="Home Value" )
melted
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 0           91940         0       77449        zip        TX    TX
# 1           91982         1       77494        zip        TX    TX
# 2           93144         2       79936        zip        TX    TX
# 3           62080         3       11368        zip        NY    NY
# 4           62093         4       11385        zip        NY    NY
# ...           ...       ...         ...        ...       ...   ...
# 7546545     80190     30657       50160        zip        IA    IA
# 7546546     65355     30657       18081        zip        PA    PA
# 7546547     82217     30657       55366        zip        MN    MN
# 7546548     80581     30657       51009        zip        IA    IA
# 7546549     65963     30657       19490        zip        PA    PA
#
#                  City                                        Metro  \
# 0                 NaN         Houston-The Woodlands-Sugar Land, TX
# ...

# %%
melted['Date'] = pd.to_datetime(melted['Date'], format='%d%m%Y')

# %%
melted
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 0           91940         0       77449        zip        TX    TX
# 1           91982         1       77494        zip        TX    TX
# 2           93144         2       79936        zip        TX    TX
# 3           62080         3       11368        zip        NY    NY
# 4           62093         4       11385        zip        NY    NY
# ...           ...       ...         ...        ...       ...   ...
# 7546545     80190     30657       50160        zip        IA    IA
# 7546546     65355     30657       18081        zip        PA    PA
# 7546547     82217     30657       55366        zip        MN    MN
# 7546548     80581     30657       51009        zip        IA    IA
# 7546549     65963     30657       19490        zip        PA    PA
#
#                  City                                        Metro  \
# 0                 NaN         Houston-The Woodlands-Sugar Land, TX
# ...

# %%
ts= melted.set_index('Date')

# %%
ts.head()
# Out:
#             RegionID  SizeRank  RegionName RegionType StateName State  \
# Date
# 2000-01-31     91940         0       77449        zip        TX    TX
# 2000-01-31     91982         1       77494        zip        TX    TX
# 2000-01-31     93144         2       79936        zip        TX    TX
# 2000-01-31     62080         3       11368        zip        NY    NY
# 2000-01-31     62093         4       11385        zip        NY    NY
#
#                 City                                  Metro        CountyName  \
# Date
# 2000-01-31       NaN   Houston-The Woodlands-Sugar Land, TX     Harris County
# 2000-01-31       NaN   Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 2000-01-31   El Paso                            El Paso, TX    El Paso County
# 2000-01-31  New York  New York-Newark-Jersey City, NY-NJ-PA     Queens County
# 2000-01-31  New York  New York-Newark-Jersey City, NY-NJ-PA     Queens County
#
#             Home Value
# Date
# 2000-01-31  107,261.00
# ...

# %% [raw]
# Filter the data:
# Keep data from the following states:  CA, WA, OR, AZ, NV
# Keep values from the years  2010 - 2020.

# %%
States=["CA","WA","OR","AZ","NV"]
ts=ts[ts['State'].isin(States)]

# %%
ts['State'].value_counts()
# Out:
# CA    432575
# WA    145475
# OR    100375
# AZ     88275
# NV     39325
# Name: State, dtype: int64

# %%
ts=ts[(ts.index.year>=2010)&(ts.index.year<=2020)]

# %%
ts.head(-5)
# Out:
#             RegionID  SizeRank  RegionName RegionType StateName State  \
# Date
# 2010-01-31     95992         5       90011        zip        CA    CA
# 2010-01-31     96361         8       91331        zip        CA    CA
# 2010-01-31     96193         9       90650        zip        CA    CA
# 2010-01-31     96083        12       90201        zip        CA    CA
# 2010-01-31     96816        13       92335        zip        CA    CA
# ...              ...       ...         ...        ...       ...   ...
# 2020-12-31     98197     30657       95433        zip        CA    CA
# 2020-12-31     98276     30657       95553        zip        CA    CA
# 2020-12-31     95117     30657       85940        zip        AZ    AZ
# 2020-12-31     98606     30657       96084        zip        CA    CA
# 2020-12-31     98507     30657       95956        zip        CA    CA
#
#                       City                                 Metro  \
# Date
# ...

# %%
ts.to_csv('data\data.csv', index = True)

# %%
resampled_data = ts.groupby('State').resample('AS').mean()
# Out:
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
resampled_data
# Out:
#                    RegionID  SizeRank  RegionName  Home Value
# State Date
# AZ    2010-01-01 125,430.67  9,836.64   85,550.34  169,930.89
#       2011-01-01 125,430.67  9,836.64   85,550.34  152,272.47
#       2012-01-01 125,430.67  9,836.64   85,550.34  159,902.06
#       2013-01-01 125,430.67  9,836.64   85,550.34  183,657.23
#       2014-01-01 125,430.67  9,836.64   85,550.34  198,551.49
#       2015-01-01 125,430.67  9,836.64   85,550.34  206,834.17
#       2016-01-01 125,430.67  9,836.64   85,550.34  217,452.80
#       2017-01-01 125,430.67  9,836.64   85,550.34  229,066.03
#       2018-01-01 125,430.67  9,836.64   85,550.34  244,689.17
#       2019-01-01 125,430.67  9,836.64   85,550.34  257,396.58
#       2020-01-01 125,430.67  9,836.64   85,550.34  278,841.94
# CA    2010-01-01  98,747.74  9,324.49   93,598.65  415,491.81
#       2011-01-01  98,747.74  9,324.49   93,598.65  388,468.03
#       2012-01-01  98,747.74  9,324.49   93,598.65  388,593.63
# ...

# %%
fig, ax = plt.subplots(figsize=(15,6))
ts.groupby('State')['Home Value'].plot(legend=True)
# Out:
# State
# AZ    Axes(0.125,0.2;0.775x0.68)
# CA    Axes(0.125,0.2;0.775x0.68)
# NV    Axes(0.125,0.2;0.775x0.68)
# OR    Axes(0.125,0.2;0.775x0.68)
# WA    Axes(0.125,0.2;0.775x0.68)
# Name: Home Value, dtype: object

# %% [markdown]
# TABLEAU :
#
# https://public.tableau.com/views/AmineArousBletExam/Story1?:language=en-GB&publish=yes&:display_count=n&:origin=viz_share_link
